# %% [markdown]
# <a href="https://colab.research.google.com/github/AJSTYLE-lab/Introduction-to-Data-Sciecne-IDS-Course/blob/main/MINI%20PROJECTS/TASK_3_L21_7692%2CTASK3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#WE HAVE TO FIND MONEY SPENDING ABILITY OF CUSTOMERS WHENEVER THEY VISIT MALL SO THERE WILL BE A RELATION BETWEEN INCOME AND SPENDING SCORE COLUMN
plt.scatter(FILE['W5'],FILE['W18'],color='grey')
plt.xlabel('WEEK_5 ')
plt.ylabel('WEEK_18 ')
plt.title('SALES_TRANSACTION_DATA')
#SCATTERING DATA IS DONE RN
# Out:
# Text(0.5, 1.0, 'SALES_TRANSACTION_DATA')

# %%
FILE = pd.read_csv("Sales_Transactions_Dataset_Weekly.csv")
print(FILE.info())#DOING PRE_PROCESSING
print("****************************************************")
print(FILE.dropna())#checking is there any null value  
print("****************************************************")
FILE.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Columns: 107 entries, Product_Code to Normalized 51
# dtypes: float64(52), int64(54), object(1)
# memory usage: 678.1+ KB
# None
# ****************************************************
#     Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8  ...  Normalized 42  \
# 0             P1  11  12  10   8  13  12  14  21   6  ...           0.06
# 1             P2   7   6   3   2   7   1   6   3   3  ...           0.20
# 2             P3   7  11   8   9  10   8   7  13  12  ...           0.27
# 3             P4  12   8  13   5   9   6   9  13  13  ...           0.41
# 4             P5   8   5  13  11   6   7   9  14   9  ...           0.27
# ..           ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...            ...
# 806         P815   0   0   1   0   0   2   1   0   0  ...           0.00
# 807         P816   0   1   0   0   1   2   2   6   0  ...           0.43
# ...

# %%
scaler = StandardScaler()
scaled_X = pd.DataFrame(scaler.fit_transform(X))
scaled_X.columns = X.columns

# %%
wcss = []
for i in range(1, 9):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 82)
    kmeans.fit(scaled_X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 9), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WEEK VALES')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(scaled_X)

# %%
plt.scatter(scaled_X[y_kmeans == 0]['W5'], scaled_X[y_kmeans == 0]['W18'], s = 20, c = 'YELLOW', label = 'CLUSTER_1')
plt.scatter(scaled_X[y_kmeans == 1]['W5'], scaled_X[y_kmeans == 1]['W18'], s = 20, c = 'ORANGE', label = 'CLUSTER_2')
plt.scatter(scaled_X[y_kmeans == 2]['W5'], scaled_X[y_kmeans == 2]['W18'], s = 20, c = 'PURPLE', label = 'CLUSTER_3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 200, c = 'RED', label = 'Centroids',marker='*')
plt.title('Clusters of sales')
plt.xlabel('5TH_week')
plt.ylabel('18_week')
plt.legend()
plt.show()

# %% [markdown]
# # DB_SCAN

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN


from sklearn.preprocessing import StandardScaler
c=pd.read_csv("Sales_Transactions_Dataset_Weekly.csv")

# %%
C = [[1,3], [5, 10], [1, 8]]
X, TRUE_LABEL = make_blobs(
    n_samples=750, centers=C, cluster_std=0.5, random_state=82
)

X = StandardScaler().fit_transform(X)

# %%
from sklearn.datasets import make_blobs
C = [[1,3], [5, 10], [1, 8]]
X, TRUE_LABEL = make_blobs(
    n_samples=750, centers=C, cluster_std=0.5, random_state=82
)

X = StandardScaler().fit_transform(X)

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
u_l=set(labels)
clrs = [plt.cm.Spectral(each) for each in np.linspace(0, 1, 11)]
for a, col in zip(u_l, clrs):
    if a == -1:
        
        col = [1, 1, 1, 1]

    M  == a
    XY= X[M & core_samples_mask]
    plt.plot( XY[0:, ],XY[:, 0],"*",markerfacecolor=tuple(col), 
    )
plt.title("NUMEBR OF CLUSTERS= %d" % n_clusters_)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-eea3af7a8bd7> in <module>
#       1 from sklearn import metrics
#       2 import matplotlib.pyplot as plt
# ----> 3 u_l=set(labels)
#       4 clrs = [plt.cm.Spectral(each) for each in np.linspace(0, 1, 11)]
#       5 for a, col in zip(u_l, clrs):
#
# NameError: name 'labels' is not defined
